# %%
import numpy as np
import pandas as pd

# ======================
# 参数
# ======================
box_size = 1e-3  # 立方体边长

n_type0 = 1000
n_type1 = 18000
n_type3 = 10000

types = (
    [0] * n_type0 +
    [1] * n_type1 +
    [3] * n_type3
)

n_total = len(types)

# ======================
# 生成随机坐标
# ======================
coords = np.random.rand(n_total, 3) * box_size  # x, y, z ∈ [0, box_size)

# ======================
# 组装 DataFrame（不打散）
# ======================
df = pd.DataFrame(coords, columns=["x", "y", "z"])
df["type"] = types
df.insert(0, "id", np.arange(n_total))  # id: 0 ~ n_total-1

# ======================
# 输出 CSV
# ======================
out_file = "sites3type_more.csv"
df.to_csv(out_file, index=False)

# 检查
print(df["type"].value_counts())
print(df.head(10))
print(df.tail(10))
# Out:
# type
# 1    18000
# 3    10000
# 0     1000
# Name: count, dtype: int64
#    id         x         y         z  type
# 0   0  0.000962  0.000912  0.000434     0
# 1   1  0.000866  0.000165  0.000785     0
# 2   2  0.000621  0.000236  0.000293     0
# 3   3  0.000223  0.000402  0.000658     0
# 4   4  0.000484  0.000136  0.000270     0
# 5   5  0.000388  0.000986  0.000506     0
# 6   6  0.000381  0.000313  0.000876     0
# 7   7  0.000294  0.000481  0.000888     0
# 8   8  0.000489  0.000665  0.000139     0
# 9   9  0.000056  0.000003  0.000727     0
#           id         x         y         z  type
# 28990  28990  0.000337  0.000892  0.000202     3
# 28991  28991  0.000649  0.000599  0.000324     3
# 28992  28992  0.000662  0.000635  0.000659     3
# 28993  28993  0.000748  0.000028  0.000943     3
# 28994  28994  0.000022  0.000639  0.000917     3
# 28995  28995  0.000186  0.000282  0.000946     3
# 28996  28996  0.000518  0.000418  0.000555     3
# 28997  28997  0.000789  0.000644  0.000305     3
# 28998  28998  0.000277  0.000094  0.000021     3
# 28999  28999  0.000168  0.000894  0.000828     3
